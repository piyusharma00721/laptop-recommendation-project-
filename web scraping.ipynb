# %%
import pandas as pd
import  requests
from bs4 import BeautifulSoup

# %%
#headers = {'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
webpage = requests.get('https://versus.com/en/laptop').text

# %%
soup = BeautifulSoup(webpage,'lxml')

# %%
len(soup.find_all('p', class_ = 'Item__name___1fPgt'))
# Out:
# 100

# %%
laptops = soup.find_all('div', class_= 'Item__nameAndProps___VwlGG')

# %%
for i in laptops:
  print(i.text.strip())
  print()
# Out:
# Lenovo ThinkPad X1 Extreme 16" WQUXGA Intel Core i9-12900H 2.5GHz / Nvidia GeForce RTX 3080 Ti Laptop / 64GB RAM / 4TB SSD
#
# _screen_size2
#
# 16"
#
# _weight_hanging_light
#
# 1.88kg
#
# _memory_light
#
# 64GB
#
# _database_light
#
# 4096GB
#
# MSI Titan 18 HX A14VIG 18" UHD Plus Intel Core i9-14900HX 2.2GHz / Nvidia GeForce RTX 4090 Laptop / 128GB RAM / 2TB SSD + 2TB SSD
#
# _screen_size2
#
# 18"
#
# _weight_hanging_light
#
# 3.6kg
#
# _memory_light
#
# 128GB
#
# _database_light
#
# 2048GB
#
# Lenovo Legion 9i Gen 8 16" Intel Core i9-13980HX 2.2GHz / Nvidia GeForce RTX 4090 Laptop / 64GB RAM / 2TB SSD
#
# _screen_size2
#
# 16"
#
# _weight_hanging_light
#
# 2.55kg
#
# _memory_light
#
# 64GB
#
# _database_light
#
# 2048GB
#
# Lenovo ThinkPad X1 Extreme 16" WQUXGA Intel Core i7-12800H 1.8GHz / Nvidia GeForce RTX 3070 Ti Laptop / 64GB RAM / 4TB SSD
#
# _screen_size2
#
# 16"
#
# _weight_hanging_light
#
# 1.88kg
#
# _memory_light
#
# 64GB
#
# _database_light
#
# 4096GB
#
# MSI Titan 18 HX A14VHG 18" UHD Plus Intel Core i9-14900HX 2.2GHz / Nvidia GeForce RTX 4080 Laptop / 64GB RAM / 2TB SSD + 2TB SSD
#
# _screen_size2
#
# 18"
#
# _weight_hanging_light
#
# 3.6kg
#
# _memory_light
#
# 64GB
#
# _database_light
#
# 2048GB
#
# Asus ROG Strix G18 (2023) 18" QHD Plus Intel Core i9-13980HX 2.2GHz / Nvidia GeForce RTX 4080 Laptop / 96GB RAM / 16TB SSD
#
# _screen_size2
#
# 18"
#
# _weight_hanging_light
#
# 3kg
#
# _memory_light
#
# 96GB
#
# _database_light
#
# 16384GB
#
# Asus ROG Zephyrus Duo 16 (2023) 16" QHD Plus AMD Ryzen 9 7945HX 2.5GHz / Nvidia GeForce RTX 4090 Laptop / 64GB RAM / 2TB SSD + 2TB SSD
#
# _screen_size2
#
# 16"
#
# _weight_hanging_light
#
# 2.67kg
#
# _memory_light
#
# 64GB
#
# _database_light
#
# 2048GB
#
# Dell Alienware M18 18" QHD Plus Intel Core i9-13900HX 2.2GHz / Nvidia GeForce RTX 4090 Laptop / 64GB RAM / 4TB SSD + 4TB SSD
#
# _screen_size2
#
# 18"
#
# _weight_hanging_light
#
# 4.04kg
#
# _memory_light
#
# 64GB
#
# _database_light
#
# 4096GB
#
# Asus ROG Strix Scar 18 (2023) 18" QHD Plus Intel Core i9-13980HX 2.2GHz / Nvidia GeForce RTX 4090 Laptop / 64GB RAM / 2TB SSD + 2TB SSD
#
# _screen_size2
#
# 18"
#
# _weight_hanging_light
#
# 3.1kg
#
# _memory_light
#
# 64GB
#
# _database_light
#
# 2048GB
#
# Lenovo ThinkPad X1 Extreme 16" WQUXGA Intel Core i7-12800H 1.8GHz / Nvidia GeForce RTX 3050 Ti Laptop / 64GB RAM / 4TB SSD + 4TB SSD
#
# _screen_size2
#
# 16"
#
# _weight_hanging_light
#
# 1.88kg
#
# _memory_light
#
# 64GB
#
# _database_light
#
# 4096GB
#
# Razer Blade 18 (2023) 18" QHD Plus Intel Core i9-13980HX 2.2GHz / Nvidia GeForce RTX 4090 Laptop / 64GB RAM / 2TB SSD
#
# _screen_size2
#
# 18"
#
# _weight_hanging_light
#
# 3.1kg
#
# _memory_light
#
# 64GB
#
# _database_light
#
# 2048GB
#
# Razer Blade 18 (2023) 18" QHD Plus Intel Core i9-13950HX 2.2GHz / Nvidia GeForce RTX 4090 Laptop / 32GB RAM / 1TB SSD + 1TB SSD
#
# _screen_size2
#
# 18"
#
# _weight_hanging_light
#
# 3.1kg
#
# _memory_light
#
# 32GB
#
# _database_light
#
# 1024GB
#
# Razer Blade 16 (2023) 16" UHD Plus Intel Core i9-13950HX 2.2GHz / Nvidia GeForce RTX 4090 Laptop / 32GB RAM / 1TB SSD + 1TB SSD
#
# _screen_size2
#
# 16"
#
# _weight_hanging_light
#
# 2.45kg
#
# _memory_light
#
# 32GB
#
# _database_light
#
# 1024GB
#
# Asus ROG Strix Scar 17 (2023) 17.3" WQHD AMD Ryzen 9 7945HX 2.5GHz / Nvidia GeForce RTX 4090 Laptop / 64GB RAM / 2TB SSD
#
# _screen_size2
#
# 17.3"
#
# _weight_hanging_light
#
# 3kg
#
# _memory_light
#
# 64GB
#
# _database_light
#
# 2048GB
#
# Asus ROG Zephyrus M16 (2023) 16" QHD Plus Intel Core i9-13900H 2.6GHz / Nvidia GeForce RTX 4090 Laptop / 64GB RAM / 2TB SSD
#
# _screen_size2
#
# 16"
#
# _weight_hanging_light
#
# 2.3kg
#
# _memory_light
#
# 64GB
#
# _database_light
#
# 2048GB
#
# Asus Zenbook Pro 16X OLED UX7602BZ 16" Intel Core i9-13905H 2.6GHz / Nvidia GeForce RTX 4080 Laptop / 16GB RAM / 2TB SSD
#
# _screen_size2
#
# 16"
#
# _weight_hanging_light
#
# 2.4kg
#
# _memory_light
#
# 32GB
#
# _database_light
#
# 2048GB
#
# Asus ROG Zephyrus Duo 16 (2023) 16" QHD Plus AMD Ryzen 9 7945HX 2.5GHz / Nvidia GeForce RTX 4080 Laptop / 64GB RAM / 2TB SSD + 2TB SSD
#
# _screen_size2
#
# 16"
#
# _weight_hanging_light
#
# 2.67kg
#
# _memory_light
#
# 64GB
#
# _database_light
#
# 2048GB
#
# MSI GT77 Titan 12UGS-008 17.3" UHD Intel Core i9-12900HX 1.5GHz / Nvidia GeForce RTX 3070 Ti Laptop / 128GB RAM / 2TB SSD
#
# _screen_size2
#
# 17.3"
#
# _weight_hanging_light
#
# 3.3kg
#
# _memory_light
#
# 128GB
#
# _database_light
#
# 2048GB
#
# Gigabyte Aorus 17X AZF (2023) 17.3" Intel Core i9-13980HX 2.2GHz / Nvidia GeForce RTX 4090 Laptop / 32GB RAM / 2TB SSD
#
# _screen_size2
#
# 17.3"
#
# _weight_hanging_light
#
# 2.8kg
#
# _memory_light
#
# 32GB
#
# _database_light
#
# 2048GB
#
# Dell Alienware M16 16" QHD Plus Intel Core i9-13900HX 2.2GHz / Nvidia GeForce RTX 4090 Laptop / 64GB RAM / 4TB SSD + 4TB SSD
#
# _screen_size2
#
# 16"
#
# _weight_hanging_light
#
# 3.25kg
#
# _memory_light
#
# 64GB
#
# _database_light
#
# 4096GB
#
# Dell Alienware M18 18" QHD Plus Intel Core i9-13900HX 2.2GHz / Nvidia GeForce RTX 4080 Laptop / 64GB RAM / 4TB SSD + 4TB SSD
#
# _screen_size2
#
# 18"
#
# _weight_hanging_light
#
# 4.04kg
#
# _memory_light
#
# 64GB
#
# _database_light
#
# 4096GB
#
# Dell Alienware x17 R2 (2022) 17.3" UHD Intel Core i7-12700H 2.3GHz / Nvidia GeForce RTX 3080 Ti Laptop / 64GB RAM / 2TB SSD + 2TB SSD
#
# _screen_size2
#
# 17.3"
#
# _weight_hanging_light
#
# 3.03kg
#
# _memory_light
#
# 64GB
#
# _database_light
#
# 2048GB
#
# Asus ROG Strix Scar 18 (2023) 18" QHD Plus Intel Core i9-13980HX 2.2GHz / Nvidia GeForce RTX 4080 Laptop / 64GB RAM / 2TB SSD + 2TB SSD
#
# _screen_size2
#
# 18"
#
# _weight_hanging_light
#
# 3.1kg
#
# _memory_light
#
# 64GB
#
# _database_light
#
# 2048GB
#
# Acer Predator Triton 17 X (2023) Intel Core i9-13900HX 2.2GHz / Nvidia GeForce RTX 4090 Laptop / 64GB RAM / 2TB SSD₹459,805
#
# _screen_size2
#
# 17"
#
# _weight_hanging_light
#
# 3kg
#
# _memory_light
#
# 64GB
#
# _database_light
#
# 2048GB
#
# Razer Blade 16 (2023) 16" QHD Plus Intel Core i9-13950HX 2.2GHz / Nvidia GeForce RTX 4080 Laptop / 32GB RAM / 1TB SSD
#
# _screen_size2
#
# 16"
#
# _weight_hanging_light
#
# 2.45kg
#
# _memory_light
#
# 32GB
#
# _database_light
#
# 1024GB
#
# Razer Blade 18 (2023) 18" QHD Plus Intel Core i9-13950HX 2.2GHz / Nvidia GeForce RTX 4080 Laptop / 32GB RAM / 1TB SSD₹335,552
#
# _screen_size2
#
# 18"
#
# _weight_hanging_light
#
# 3.1kg
#
# _memory_light
#
# 32GB
#
# _database_light
#
# 1024GB
#
# Lenovo Legion Pro 7i 16" WQXGA Intel Core i9-13900HX 2.2GHz / Nvidia GeForce RTX 4080 Laptop / 32GB RAM / 1TB SSD + 1TB SSD
#
# _screen_size2
#
# 16"
#
# _weight_hanging_light
#
# 2.8kg
#
# _memory_light
#
# 32GB
#
# _database_light
#
# 1024GB
#
# Dell Alienware x17 R2 (2022) 17.3" UHD Intel Core i9-12900HK 2.5GHz / Nvidia GeForce RTX 3080 Ti Laptop / 64GB RAM / 2TB SSD + 2TB SSD
#
# _screen_size2
#
# 17.3"
#
# _weight_hanging_light
#
# 3kg
#
# _memory_light
#
# 64GB
#
# _database_light
#
# 2048GB
#
# Razer Blade 17 (2022) 17.3" UHD Intel Core i9-12900H 1.8GHz / Nvidia GeForce RTX 3080 Ti Laptop / 32GB RAM / 1TB SSD
#
# _screen_size2
#
# 17.3"
#
# _weight_hanging_light
#
# 2.75kg
#
# _memory_light
#
# 32GB
#
# _database_light
#
# 1024GB
#
# Asus ROG Zephyrus Duo 16 (2022) GX650 16" AMD Ryzen 9 6900HX 3.3GHz / Nvidia GeForce RTX 3080 Ti Laptop / 64GB RAM / 4TB SSD + 4TB SSD
#
# _screen_size2
#
# 16"
#
# _weight_hanging_light
#
# 2.55kg
#
# _memory_light
#
# 64GB
#
# _database_light
#
# 2048GB
#
# Asus ROG Zephyrus Duo 16 (2022) GX650 16" AMD Ryzen 9 6900HX 3.3GHz / Nvidia GeForce RTX 3080 Laptop / 64GB RAM / 2TB SSD + 2TB SSD
#
# _screen_size2
#
# 16"
#
# _weight_hanging_light
#
# 2.55kg
#
# _memory_light
#
# 32GB
#
# _database_light
#
# 2048GB
#
# Asus ROG Strix Scar 17 (2023) 17.3" WQHD AMD Ryzen 9 7945HX 2.5GHz / Nvidia GeForce RTX 4080 Laptop / 64GB RAM / 2TB SSD
#
# _screen_size2
#
# 17.3"
#
# _weight_hanging_light
#
# 3kg
#
# _memory_light
#
# 64GB
#
# _database_light
#
# 2048GB
#
# Asus ROG Zephyrus M16 (2023) 16" QHD Plus Intel Core i9-13900H 2.6GHz / Nvidia GeForce RTX 4080 Laptop / 64GB RAM / 2TB SSD
#
# _screen_size2
#
# 16"
#
# _weight_hanging_light
#
# 2.3kg
#
# _memory_light
#
# 64GB
#
# _database_light
#
# 2048GB
#
# Asus ROG Strix G16 (2023) 16" QHD Plus Intel Core i9-13980HX 2.2GHz / Nvidia GeForce RTX 4080 Laptop / 32GB RAM / 2TB SSD
#
# _screen_size2
#
# 16"
#
# _weight_hanging_light
#
# 2.5kg
#
# _memory_light
#
# 32GB
#
# _database_light
#
# 2048GB
#
# Asus ROG Strix G18 (2023) 18" QHD Plus Intel Core i9-13980HX 2.2GHz / Nvidia GeForce RTX 4070 Laptop / 64GB RAM / 4TB SSD
#
# _screen_size2
#
# 18"
#
# _weight_hanging_light
#
# 3kg
#
# _memory_light
#
# 64GB
#
# _database_light
#
# 4096GB
#
# Gigabyte Aorus 17X AZF (2023) 17.3" Intel Core i9-13950HX 2.2GHz / Nvidia GeForce RTX 4090 Laptop / 32GB RAM / 2TB SSD
#
# _screen_size2
#
# 17.3"
#
# _weight_hanging_light
#
# 2.8kg
#
# _memory_light
#
# 32GB
#
# _database_light
#
# 2048GB
#
# Asus ROG Zephyrus Duo 16 (2023) 16" QHD Plus AMD Ryzen 9 7945HX 2.5GHz / Nvidia GeForce RTX 4070 Laptop / 64GB RAM / 2TB SSD + 2TB SSD
#
# _screen_size2
#
# 16"
#
# _weight_hanging_light
#
# 2.67kg
#
# _memory_light
#
# 64GB
#
# _database_light
#
# 2048GB
#
# Dell Alienware X17 R1 Intel Core i9-11980HK 2.6GHz / Nvidia GeForce RTX 3080 Laptop / 64GB RAM / 4TB SSD
#
# _screen_size2
#
# 17.3"
#
# _weight_hanging_light
#
# 3.2kg
#
# _memory_light
#
# 64GB
#
# _database_light
#
# 4000GB
#
# Razer Blade 15 (2022) 15.6" UHD Intel Core i9-12900H 1.8GHz / Nvidia GeForce RTX 3080 Ti Laptop / 32GB RAM / 1TB SSD
#
# _screen_size2
#
# 15.6"
#
# _weight_hanging_light
#
# 2kg
#
# _memory_light
#
# 16GB
#
# _database_light
#
# 1024GB
#
# Asus ROG Zephyrus Duo 16 (2022) GX650 16" AMD Ryzen 9 6900HX 3.3GHz / Nvidia GeForce RTX 3070 Ti Laptop / 64GB RAM / 8TB SSD + 8TB SSD
#
# _screen_size2
#
# 16"
#
# _weight_hanging_light
#
# 2.6kg
#
# _memory_light
#
# 64GB
#
# _database_light
#
# 8192GB
#
# Asus ROG Strix Scar 16 (2023) 16" QHD Plus Intel Core i9-13980HX 2.2GHz / Nvidia GeForce RTX 4090 Laptop / 64GB RAM / 2TB SSD + 2TB SSD
#
# _screen_size2
#
# 16"
#
# _weight_hanging_light
#
# 2.6kg
#
# _memory_light
#
# 64GB
#
# _database_light
#
# 2048GB
#
# MSI CreatorPro Z17 A12UMST-200ES 17" QHD Plus Intel Core i9-12900H 2.5GHz / Nvidia RTX A5500 Laptop / 64GB RAM / 2TB SSD
#
# _screen_size2
#
# 17"
#
# _weight_hanging_light
#
# 2.49kg
#
# _memory_light
#
# 64GB
#
# _database_light
#
# 2048GB
#
# Dell Alienware M16 16" QHD Plus Intel Core i9-13900HX 2.2GHz / Nvidia GeForce RTX 4080 Laptop / 64GB RAM / 4TB SSD + 4TB SSD
#
# _screen_size2
#
# 16"
#
# _weight_hanging_light
#
# 3.25kg
#
# _memory_light
#
# 64GB
#
# _database_light
#
# 4096GB
#
# Asus ROG Zephyrus Duo 16 (2023) 16" QHD Plus AMD Ryzen 9 7945HX 2.5GHz / Nvidia GeForce RTX 4060 Laptop / 64GB RAM / 2TB SSD + 2TB SSD
#
# _screen_size2
#
# 16"
#
# _weight_hanging_light
#
# 2.67kg
#
# _memory_light
#
# 64GB
#
# _database_light
#
# 2048GB
#
# MSI GE76 Raider 12UHS 239 17.3" UHD Intel Core i9-12900HK 2.5GHz / Nvidia GeForce RTX 3080 Ti Laptop / 64GB RAM / 2TB SSD + 1TB SSD
#
# _screen_size2
#
# 17.3"
#
# _weight_hanging_light
#
# 2.9kg
#
# _memory_light
#
# 64GB
#
# _database_light
#
# 2048GB
#
# Asus ROG Zephyrus G14 (2023) 14" QHD Plus AMD Ryzen 9 7940HS 4GHz / Nvidia GeForce RTX 4090 Laptop / 32GB RAM / 1TB SSD
#
# _screen_size2
#
# 14"
#
# _weight_hanging_light
#
# 1.72kg
#
# _memory_light
#
# 32GB
#
# _database_light
#
# 1024GB
#
# Dell Alienware M18 18" QHD Plus Intel Core i7-13700HX 2.1GHz / Nvidia GeForce RTX 4070 Laptop / 64GB RAM / 4TB SSD + 4TB SSD₹383,307
#
# _screen_size2
#
# 18"
#
# _weight_hanging_light
#
# 4.04kg
#
# _memory_light
#
# 64GB
#
# _database_light
#
# 4096GB
#
# Dell Alienware M18 18" QHD Plus Intel Core i9-13900HX 2.2GHz / Nvidia GeForce RTX 4060 Laptop / 64GB RAM / 4TB SSD + 4TB SSD
#
# _screen_size2
#
# 18"
#
# _weight_hanging_light
#
# 4.04kg
#
# _memory_light
#
# 64GB
#
# _database_light
#
# 4096GB
#
# Dell Alienware m17 R5 17.3" FHD AMD Ryzen 9 6900HX 3.3GHz / Nvidia GeForce RTX 3080 Ti Laptop / 64GB RAM / 4TB SSD
#
# _screen_size2
#
# 17.3"
#
# _weight_hanging_light
#
# 3.3kg
#
# _memory_light
#
# 64GB
#
# _database_light
#
# 4000GB
#
# Gigabyte Aorus 17X AXF (2023) 17.3" Intel Core i9-13980HX 2.2GHz / Nvidia GeForce RTX 4080 Laptop / 16GB RAM / 1TB SSD
#
# _screen_size2
#
# 17.3"
#
# _weight_hanging_light
#
# 2.8kg
#
# _memory_light
#
# 16GB
#
# _database_light
#
# 1024GB
#
# MSI GT77 Titan 12UHS-006 17.3" UHD Intel Core i9-12900HX 2.3GHz / Nvidia GeForce RTX 3080 Ti Laptop / 64GB RAM / 2TB SSD
#
# _screen_size2
#
# 17.3"
#
# _weight_hanging_light
#
# 3.3kg
#
# _memory_light
#
# 64GB
#
# _database_light
#
# 2048GB
#
# Razer Blade 18 (2023) 18" QHD Plus Intel Core i9-13950HX 2.2GHz / Nvidia GeForce RTX 4070 Laptop / 32GB RAM / 1TB SSD
#
# _screen_size2
#
# 18"
#
# _weight_hanging_light
#
# 3.1kg
#
# _memory_light
#
# 32GB
#
# _database_light
#
# 1024GB
#
# Asus ROG Flow X16 (2023) 16" QHD Plus Intel Core i9-13900H 2.6GHz / Nvidia GeForce RTX 4070 Laptop / 16GB RAM / 2TB SSD
#
# _screen_size2
#
# 16"
#
# _weight_hanging_light
#
# 2.2kg
#
# _memory_light
#
# 16GB
#
# _database_light
#
# 2048GB
#
# Dell Alienware X16 (2023) 16" QHD Plus Intel Core i9-13900HK 2.6GHz / Nvidia GeForce RTX 4090 Laptop / 32GB RAM / 4TB SSD
#
# _screen_size2
#
# 16"
#
# _weight_hanging_light
#
# 2.72kg
#
# _memory_light
#
# 32GB
#
# _database_light
#
# 4096GB
#
# Gigabyte Aorus 17X AZF (2023) 17.3" Intel Core i9-13900HX 2.2GHz / Nvidia GeForce RTX 4090 Laptop / 32GB RAM / 2TB SSD
#
# _screen_size2
#
# 17.3"
#
# _weight_hanging_light
#
# 2.8kg
#
# _memory_light
#
# 32GB
#
# _database_light
#
# 2048GB
#
# Razer Blade 16 (2023) 16" UHD Plus Intel Core i9-13950HX 2.2GHz / Nvidia GeForce RTX 4070 Laptop / 32GB RAM / 1TB SSD
#
# _screen_size2
#
# 16"
#
# _weight_hanging_light
#
# 2.45kg
#
# _memory_light
#
# 32GB
#
# _database_light
#
# 1024GB
#
# Lenovo ThinkPad X1 Yoga Gen 7 14" WQUXGA OLED Intel Core i7-1260P 2.1GHz / 32GB RAM / 2TB SSD
#
# _screen_size2
#
# 14"
#
# _weight_hanging_light
#
# 1.38kg
#
# _memory_light
#
# 32GB
#
# _database_light
#
# 2048GB
#
# ASUS Zenbook Pro 16X OLED (UX7602) 16" Intel Core i9-12900H 2.5GHz / Nvidia GeForce RTX 3060 Laptop / 32GB RAM / 2TB SSD₹301,905
#
# _screen_size2
#
# 16"
#
# _weight_hanging_light
#
# 2.4kg
#
# _memory_light
#
# 32GB
#
# _database_light
#
# 2048GB
#
# Gigabyte Aorus 17X AXF (2023) 17.3" Intel Core i9-13900HX 2.2GHz / Nvidia GeForce RTX 4080 Laptop / 16GB RAM / 1TB SSD₹248,596
#
# _screen_size2
#
# 17.3"
#
# _weight_hanging_light
#
# 2.8kg
#
# _memory_light
#
# 16GB
#
# _database_light
#
# 1024GB
#
# Asus ROG Zephyrus G16 (2023) 16" QHD Plus Intel Core i7-12700H 2.3GHz / Nvidia GeForce RTX 4070 Laptop / 32GB RAM / 2TB SSD
#
# _screen_size2
#
# 16"
#
# _weight_hanging_light
#
# 2kg
#
# _memory_light
#
# 32GB
#
# _database_light
#
# 2048GB
#
# Dell Alienware x17 R2 (2022) 17.3" UHD Intel Core i7-12700H 2.3GHz / Nvidia GeForce RTX 3070 Ti Laptop / 64GB RAM / 2TB SSD + 2TB SSD
#
# _screen_size2
#
# 17.3"
#
# _weight_hanging_light
#
# 2.69kg
#
# _memory_light
#
# 64GB
#
# _database_light
#
# 2048GB
#
# MSI CreatorPro Z16P B12UMST-089 16" QHD Plus Intel Core i9-12900H 1.8GHz / Nvidia RTX A5500 Laptop / 64GB RAM / 1TB SSD
#
# _screen_size2
#
# 16"
#
# _weight_hanging_light
#
# 2.38kg
#
# _memory_light
#
# 64GB
#
# _database_light
#
# 1024GB
#
# Razer Blade 15 (2022) 15.6" FHD Intel Core i7-12800H 1.8GHz / Nvidia GeForce RTX 3080 Ti Laptop / 32GB RAM / 1TB SSD₹304,309
#
# _screen_size2
#
# 15.6"
#
# _weight_hanging_light
#
# 2kg
#
# _memory_light
#
# 32GB
#
# _database_light
#
# 1024GB
#
# Asus ROG Zephyrus M16 (2023) 16" QHD Plus Intel Core i9-13900H 2.6GHz / Nvidia GeForce RTX 4070 Laptop / 64GB RAM / 2TB SSD
#
# _screen_size2
#
# 16"
#
# _weight_hanging_light
#
# 2.3kg
#
# _memory_light
#
# 64GB
#
# _database_light
#
# 2048GB
#
# Asus ROG Flow X16 (2023) 16" QHD Plus Intel Core i9-13900H 2.6GHz / Nvidia GeForce RTX 4060 Laptop / 16GB RAM / 2TB SSD
#
# _screen_size2
#
# 16"
#
# _weight_hanging_light
#
# 2.2kg
#
# _memory_light
#
# 16GB
#
# _database_light
#
# 2048GB
#
# Asus ROG Strix G18 (2023) 18" QHD Plus Intel Core i9-13980HX 2.2GHz / Nvidia GeForce RTX 4060 Laptop / 32GB RAM / 2TB SSD
#
# _screen_size2
#
# 18"
#
# _weight_hanging_light
#
# 3kg
#
# _memory_light
#
# 32GB
#
# _database_light
#
# 2048GB
#
# Asus ROG Strix G17 (2023) 17.3" WQHD AMD Ryzen 9 7945HX 2.5GHz / Nvidia GeForce RTX 4070 Laptop / 32GB RAM / 2TB SSD
#
# _screen_size2
#
# 17.3"
#
# _weight_hanging_light
#
# 2.8kg
#
# _memory_light
#
# 32GB
#
# _database_light
#
# 2048GB
#
# Asus ProArt StudioBook 16 OLED H7600ZX 16" Intel Core i7-12700H 2.3GHz / Nvidia GeForce RTX 3080 Ti Laptop / 32GB RAM / 1TB SSD + 1TB SSD
#
# _screen_size2
#
# 16"
#
# _weight_hanging_light
#
# 2.4kg
#
# _memory_light
#
# 32GB
#
# _database_light
#
# 1024GB
#
# MSI Vector GP68HX 16" QHD Plus Intel Core i9-13950HX 2.2GHz / Nvidia GeForce RTX 4060 Laptop / 32GB RAM / 1TB SSD
#
# _screen_size2
#
# 16"
#
# _weight_hanging_light
#
# 2.67kg
#
# _memory_light
#
# 32GB
#
# _database_light
#
# 1024GB
#
# MSI GS77 Stealth 12UHS-040 17.3" UHD Intel Core i9-12900H 1.8GHz / Nvidia GeForce RTX 3080 Ti Laptop / 32GB RAM / 1TB SDD
#
# _screen_size2
#
# 17.3"
#
# _weight_hanging_light
#
# 2.8kg
#
# _memory_light
#
# 32GB
#
# _database_light
#
# 1024GB
#
# Asus ROG Zephyrus G16 (2023) 16" QHD Plus Intel Core i7-12700H 2.3GHz / Nvidia GeForce RTX 4060 Laptop / 32GB RAM / 2TB SSD
#
# _screen_size2
#
# 16"
#
# _weight_hanging_light
#
# 2kg
#
# _memory_light
#
# 32GB
#
# _database_light
#
# 2048GB
#
# Razer Blade 16 (2023) 16" QHD Plus Intel Core i9-13950HX 2.2GHz / Nvidia GeForce RTX 4060 Laptop / 16GB RAM / 1TB SSD₹249,695
#
# _screen_size2
#
# 16"
#
# _weight_hanging_light
#
# 2.45kg
#
# _memory_light
#
# 16GB
#
# _database_light
#
# 1024GB
#
# Dell Alienware M18 18" QHD Plus Intel Core i7-13700HX 2.1GHz / Nvidia GeForce RTX 4060 Laptop / 64GB RAM / 4TB SSD + 4TB SSD
#
# _screen_size2
#
# 18"
#
# _weight_hanging_light
#
# 4.04kg
#
# _memory_light
#
# 64GB
#
# _database_light
#
# 4096GB
#
# Razer Blade 18 (2023) 18" QHD Plus Intel Core i9-13950HX 2.2GHz / Nvidia GeForce RTX 4060 Laptop / 16GB RAM / 1TB SSD₹282,521
#
# _screen_size2
#
# 18"
#
# _weight_hanging_light
#
# 3.1kg
#
# _memory_light
#
# 16GB
#
# _database_light
#
# 1024GB
#
# Asus ROG Zephyrus M16 (2022) GU603 16" Intel Core i9-12900H 2.5GHz / Nvidia GeForce RTX 3080 Ti Laptop / 16GB RAM / 2TB SSD
#
# _screen_size2
#
# 16"
#
# _weight_hanging_light
#
# 2kg
#
# _memory_light
#
# 16GB
#
# _database_light
#
# 2048GB
#
# Asus ROG Strix Scar 15 (2022) G533 15.6" Intel Core i9-12900H 2.5GHz / Nvidia GeForce RTX 3080 Ti Laptop / 64GB RAM / 2TB SSD
#
# _screen_size2
#
# 15.6"
#
# _weight_hanging_light
#
# 2.3kg
#
# _memory_light
#
# 64GB
#
# _database_light
#
# 2048GB
#
# Dell Alienware m15 R7 (2022) 15.6" QHD Intel Core i7-12700H 2.3GHz / Nvidia GeForce RTX 3080 Ti Laptop / 64GB RAM / 2TB SSD + 2TB SSD
#
# _screen_size2
#
# 15.6"
#
# _weight_hanging_light
#
# 2.69kg
#
# _memory_light
#
# 64GB
#
# _database_light
#
# 2048GB
#
# Asus ROG Flow X16 (2022) GV601 16" QHD Plus AMD Ryzen 9 6900HS 3.3GHz / Nvidia GeForce RTX 3070 Ti Laptop / 64GB RAM / 2TB SSD
#
# _screen_size2
#
# 16"
#
# _weight_hanging_light
#
# 2.1kg
#
# _memory_light
#
# 64GB
#
# _database_light
#
# 2048GB
#
# Asus ROG Strix Scar 17 (2022) G733 17.3" Intel Core i9-12900H 2.5GHz / Nvidia GeForce RTX 3080 Ti Laptop / 64GB RAM / 2TB SSD
#
# _screen_size2
#
# 17.3"
#
# _weight_hanging_light
#
# 2.9kg
#
# _memory_light
#
# 64GB
#
# _database_light
#
# 2048GB
#
# Asus ROG Zephyrus G16 (2023) 16" QHD Plus Intel Core i9-13900H 2.6GHz / Nvidia GeForce RTX 4070 Laptop / 32GB RAM / 2TB SSD
#
# _screen_size2
#
# 16"
#
# _weight_hanging_light
#
# 2kg
#
# _memory_light
#
# 32GB
#
# _database_light
#
# 2048GB
#
# Asus ROG Strix G16 (2023) 16" QHD Plus Intel Core i9-13980HX 2.2GHz / Nvidia GeForce RTX 4070 Laptop / 32GB RAM / 2TB SSD
#
# _screen_size2
#
# 16"
#
# _weight_hanging_light
#
# 2.5kg
#
# _memory_light
#
# 32GB
#
# _database_light
#
# 2048GB
#
# Asus ROG Strix G16 (2023) 16" QHD Plus Intel Core i9-13980HX 2.2GHz / Nvidia GeForce RTX 4060 Laptop / 32GB RAM / 2TB SSD
#
# _screen_size2
#
# 16"
#
# _weight_hanging_light
#
# 2.5kg
#
# _memory_light
#
# 32GB
#
# _database_light
#
# 2048GB
#
# Asus ROG Strix G17 (2023) 17.3" WQHD AMD Ryzen 9 7945HX 2.5GHz / Nvidia GeForce RTX 4060 Laptop / 32GB RAM / 2TB SSD
#
# _screen_size2
#
# 17.3"
#
# _weight_hanging_light
#
# 2.8kg
#
# _memory_light
#
# 32GB
#
# _database_light
#
# 2048GB
#
# HP Omen 17-ck1003np 17" QHD Intel Core i9-12900HX 2.3GHz / Nvidia GeForce RTX 3080 Ti Laptop / 32GB RAM / 1TB SSD
#
# _screen_size2
#
# 17.3"
#
# _weight_hanging_light
#
# 2.78kg
#
# _memory_light
#
# 32GB
#
# _database_light
#
# 1024GB
#
# Dell Alienware X17 R1 Intel Core i7-11800H 2.3GHz / Nvidia GeForce RTX 3080 Laptop / 32GB RAM / 512GB SSD
#
# _screen_size2
#
# 17.3"
#
# _weight_hanging_light
#
# 3.2kg
#
# _memory_light
#
# 32GB
#
# _database_light
#
# 512GB
#
# Asus ROG Strix Scar 16 (2023) 16" QHD Plus Intel Core i9-13980HX 2.2GHz / Nvidia GeForce RTX 4080 Laptop / 64GB RAM / 2TB SSD + 2TB SSD
#
# _screen_size2
#
# 16"
#
# _weight_hanging_light
#
# 2.6kg
#
# _memory_light
#
# 64GB
#
# _database_light
#
# 2048GB
#
# Asus ROG Flow X16 (2023) 16" QHD Plus Intel Core i9-13900H 2.6GHz / Nvidia GeForce RTX 4050 Laptop / 16GB RAM / 2TB SSD
#
# _screen_size2
#
# 16"
#
# _weight_hanging_light
#
# 2.2kg
#
# _memory_light
#
# 16GB
#
# _database_light
#
# 2048GB
#
# Gigabyte AERO 16 YE5 16" Intel Core i9-12900H 2.5GHz / Nvidia GeForce RTX 3080 Ti Laptop / 32GB RAM / 2TB SSD
#
# _screen_size2
#
# 16"
#
# _weight_hanging_light
#
# 4.23kg
#
# _memory_light
#
# 32GB
#
# _database_light
#
# 2048GB
#
# MSI Vector GP68HX 16" FHD Plus Intel Core i9-12900H 2.5GHz / Nvidia GeForce RTX 4080 Laptop / 64GB RAM / 2TB SSD
#
# _screen_size2
#
# 16"
#
# _weight_hanging_light
#
# 2.67kg
#
# _memory_light
#
# 64GB
#
# _database_light
#
# 2048GB
#
# MSI Creator Z17 A12UGST 049 17" QHD+ Intel Core i7-12700H 2.3GHz / Nvidia GeForce RTX 3070 Ti Laptop / 64GB RAM / 2TB SSD + 2TB SSD
#
# _screen_size2
#
# 17"
#
# _weight_hanging_light
#
# 2.49kg
#
# _memory_light
#
# 64GB
#
# _database_light
#
# 2048GB
#
# HP Omen 17-ck1010np 17" QHD Intel Core i9-12900H 2.5GHz / Nvidia GeForce RTX 3080 Ti Laptop / 32GB RAM / 1TB SSD
#
# _screen_size2
#
# 17.3"
#
# _weight_hanging_light
#
# 2.78kg
#
# _memory_light
#
# 32GB
#
# _database_light
#
# 1024GB
#
# Dell Alienware M16 16" QHD Plus Intel Core i9-13900HX 2.2GHz / Nvidia GeForce RTX 4070 Laptop / 64GB RAM / 4TB SSD + 4TB SSD
#
# _screen_size2
#
# 16"
#
# _weight_hanging_light
#
# 3.25kg
#
# _memory_light
#
# 64GB
#
# _database_light
#
# 4096GB
#
# Dell Alienware x17 R2 (2022) 17.3" UHD Intel Core i7-12700H 2.3GHz / Nvidia GeForce RTX 3060 Laptop / 64GB RAM / 2TB SSD + 2TB SSD
#
# _screen_size2
#
# 17.3"
#
# _weight_hanging_light
#
# 3.03kg
#
# _memory_light
#
# 64GB
#
# _database_light
#
# 2048GB
#
# Asus ROG Strix G18 (2023) 18" QHD Plus Intel Core i9-13980HX 2.2GHz / Nvidia GeForce RTX 4050 Laptop / 32GB RAM / 2TB SSD
#
# _screen_size2
#
# 18"
#
# _weight_hanging_light
#
# 3kg
#
# _memory_light
#
# 32GB
#
# _database_light
#
# 2048GB
#
# Asus ROG Zephyrus G16 (2023) 16" QHD Plus Intel Core i7-12700H 2.3GHz / Nvidia GeForce RTX 4050 Laptop / 32GB RAM / 2TB SSD
#
# _screen_size2
#
# 16"
#
# _weight_hanging_light
#
# 2kg
#
# _memory_light
#
# 32GB
#
# _database_light
#
# 2048GB
#
# HP Omen 17-ck2001np 17" QHD Intel Core i7-13700HX 2.1GHz / Nvidia GeForce RTX 4080 Laptop / 32GB RAM / 1TB SSD
#
# _screen_size2
#
# 17.3"
#
# _weight_hanging_light
#
# 2.78kg
#
# _memory_light
#
# 32GB
#
# _database_light
#
# 1024GB
#
# Asus Zenbook Pro 14 OLED UX6404VI 14.5" Intel Core i9-13900H 2.6GHz / Nvidia GeForce RTX 4070 Laptop / 32GB RAM / 1TB SSD₹201,715
#
# _screen_size2
#
# 14.5"
#
# _weight_hanging_light
#
# 1.65kg
#
# _memory_light
#
# 32GB
#
# _database_light
#
# 1024GB
#
# Asus ROG Zephyrus G16 (2023) 16" QHD Plus Intel Core i9-13900H 2.6GHz / Nvidia GeForce RTX 4060 Laptop / 32GB RAM / 2TB SSD
#
# _screen_size2
#
# 16"
#
# _weight_hanging_light
#
# 2kg
#
# _memory_light
#
# 32GB
#
# _database_light
#
# 2048GB
#
# MSI WS66 11UM-214RU 15.6" UHD Intel Core i9-11900H 2.5GHz / Nvidia RTX A5000 16GB Laptop / 32GB RAM / 1TB SSD
#
# _screen_size2
#
# 15.6"
#
# _weight_hanging_light
#
# 2.1kg
#
# _memory_light
#
# 32GB
#
# _database_light
#
# 1000GB
#
# MSI GS77 Stealth 12UHS-083 17.3" QHD Intel Core i7-12700H 1.7GHz / Nvidia GeForce RTX 3080 Ti Laptop / 32GB RAM / 1TB SSD
#
# _screen_size2
#
# 17.3"
#
# _weight_hanging_light
#
# 2.8kg
#
# _memory_light
#
# 32GB
#
# _database_light
#
# 1024GB
